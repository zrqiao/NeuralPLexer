# %%
import pandas as pd
import seaborn
# Out:
# /var/folders/p7/w3v0h0sj79b__vhxymx1tvbw0000gn/T/ipykernel_39967/4068064624.py:4: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('svg')

# %%
import seaborn as sns
from matplotlib import pyplot as plt
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('svg')
plt.figure(figsize=(3, 30), dpi=300)
df0 = df.sort_values("plddt", ascending=False).drop_duplicates("sample_id")
sns.scatterplot(data=df0, x="TMScore", y="sample_id", label="NeuralPLexer", color='#DC0000FF')
sns.scatterplot(data=df0, x="TMScore_template_ref", y="sample_id", label="AlphaFold", color='#3C5488FF')
plt.legend(frameon=False)
plt.ylabel("Target")
plt.xlabel("Structure Accuracy (TM-score)")
plt.show()
print(len(df0), len(df0[df0["TMScore"]>df0["TMScore_template_ref"]]))
# Out:
# /var/folders/p7/w3v0h0sj79b__vhxymx1tvbw0000gn/T/ipykernel_39967/907034912.py:4: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('svg')
# 56 26

# %%
# PocketMiner
df_paths =  [
    f"test_results/pocketminer_3mgpnx3g-epoch56-EMA_032723/default/af2_template_msa512/inferred_prior/langevin_simulated_annealing_T1.0_NFE100/model{i}/summary.csv" for i in range(1, 5)
] 
df = pd.concat(pd.read_csv(dp) for dp in df_paths)
df_paths =  [
    f"test_results/pocketminer_3mgpnx3g-epoch56-EMA_032723/default/af2_template_msa512/discard_ligand/langevin_simulated_annealing_T1.0_NFE100/model{i}/summary.csv" for i in range(1, 5)
] 
df1 = pd.concat(pd.read_csv(dp) for dp in df_paths)
df["TMScore_noligand"] = df1["TMScore"]
plt.figure(figsize=(4, 12), dpi=300)
df0 = df.sort_values("plddt", ascending=False).drop_duplicates("sample_id").sort_values("TMScore", ascending=False)
sns.scatterplot(data=df0, x="TMScore_template_ref", y="sample_id", label="AlphaFold", color='#3C5488FF', alpha=0.8)
sns.scatterplot(data=df0, x="TMScore_noligand", y="sample_id", label="NeuralPLexer (no ligand)", color='grey', alpha=0.8)
sns.scatterplot(data=df0, x="TMScore", y="sample_id", label="NeuralPLexer", color='#DC0000FF', alpha=0.8)
plt.legend(frameon=False)
plt.ylabel("Target PDB ID")
plt.xlabel("Structure Prediction Accuracy (TM-score)")
plt.title("PocketMiner")
plt.show()
print(len(df0), len(df0[df0["TMScore"]>df0["TMScore_template_ref"]]))
# Out:
# 56 26

# %%
# PocketMiner
df_paths =  [
    f"test_results/apoholo2019+_3mgpnx3g-epoch56-EMA_032723/default/af2_template_msa512/inferred_prior/langevin_simulated_annealing_T1.0_NFE100/model{i}/summary.csv" for i in range(1, 5)
]
df = pd.concat(pd.read_csv(dp) for dp in df_paths)
df_paths =  [
    f"test_results/apoholo2019+_3mgpnx3g-epoch56-EMA_032723/default/af2_template_msa512/discard_ligand/langevin_simulated_annealing_T1.0_NFE100/model{i}/summary.csv" for i in range(1, 5)
] 
df1 = pd.concat(pd.read_csv(dp) for dp in df_paths)
df["TMScore_noligand"] = df1["TMScore"]
plt.figure(figsize=(4, 12), dpi=300)
df0 = df.sort_values("plddt", ascending=False).drop_duplicates("sample_id").sort_values("TMScore", ascending=False)
df0 = df0[:60]
sns.scatterplot(data=df0, x="TMScore_template_ref", y="sample_id", label="AlphaFold", color='#3C5488FF', alpha=0.8)
sns.scatterplot(data=df0, x="TMScore_noligand", y="sample_id", label="NeuralPLexer (no ligand)", color='grey', alpha=0.8)
sns.scatterplot(data=df0, x="TMScore", y="sample_id", label="NeuralPLexer", color='#DC0000FF', alpha=0.8)
plt.legend(frameon=False)
plt.xlim(0.6, 1.01)
plt.ylabel("Target PDB ID")
plt.xlabel("Structure Prediction Accuracy (TM-score)")
plt.title("Recent structures")
plt.show()
print(len(df0), len(df0[df0["TMScore"]>df0["TMScore_template_ref"]]))
# Out:
# 60 31

# %%
# PocketMiner
df_paths =  [
    f"test_results/apoholo2019+_3mgpnx3g-epoch56-EMA_032723/default/af2_template_msa512/inferred_prior/langevin_simulated_annealing_T1.0_NFE100/model{i}/summary.csv" for i in range(1, 5)
]
df = pd.concat(pd.read_csv(dp) for dp in df_paths)
df_paths =  [
    f"test_results/apoholo2019+_3mgpnx3g-epoch56-EMA_032723/default/af2_template_msa512/discard_ligand/langevin_simulated_annealing_T1.0_NFE100/model{i}/summary.csv" for i in range(1, 5)
] 
df1 = pd.concat(pd.read_csv(dp) for dp in df_paths)
df["TMScore_noligand"] = df1["TMScore"]
plt.figure(figsize=(4, 12), dpi=300)
df0 = df.sort_values("plddt", ascending=False).drop_duplicates("sample_id").sort_values("TMScore", ascending=False)
df0 = df0[60:]
sns.scatterplot(data=df0, x="TMScore_template_ref", y="sample_id", label="AlphaFold", color='#3C5488FF', alpha=0.8)
sns.scatterplot(data=df0, x="TMScore_noligand", y="sample_id", label="NeuralPLexer (no ligand)", color='grey', alpha=0.8)
sns.scatterplot(data=df0, x="TMScore", y="sample_id", label="NeuralPLexer", color='#DC0000FF', alpha=0.8)
plt.legend(frameon=False)
plt.ylabel("Target PDB ID")
plt.xlabel("Structure Prediction Accuracy (TM-score)")
plt.title("Recent structures (continued)")
plt.show()
print(len(df0), len(df0[df0["TMScore"]>df0["TMScore_template_ref"]]))
# Out:
# 58 27
